# %% [markdown]
# ___
# ## Problem statement
# ___
#
# Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.
#
# You may assume that each input would have exactly one solution, and you may not use the same element twice.
#
# You can return the answer in any order.
#
# ___
# ## Examples
# ___
#
# **Example 1:**
#
# Input: nums = [2,7,11,15], target = 9
#
# Output: [0,1]
#
# Explanation: Because nums[0] + nums[1] == 9, we return [0, 1].
#
# **Example 2:**
#
# Input: nums = [3,2,4], target = 6
#
# Output: [1,2]
#
# **Example 3:**
#
# Input: nums = [3,3], target = 6
#
# Output: [0,1]
#
# ___
# ## Constraints
# ___
#
# 2 <= nums.length <= 104
#
# -109 <= nums[i] <= 109
#
# -109 <= target <= 109
#
# Only one valid answer exists.
#
#
# **Follow-up:**
# Can you come up with an algorithm that is less than O(n2) time complexity?

# %%
# Naive solution O(n^2) time complexity + O(1) memory
class Solution(object):
    def twoSum(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[int]
        """

        for i in range(len(nums)):
            for j in range(len(nums)):
                if i != j:
                    if nums[i] + nums[j] == target:
                        return [i, j]

# %%
# O(n) time complexity + O(n) memory
class Solution(object):
    def twoSum(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[int]

        Notes (v0.1)
        --------------
        (1) When using lookup tables think about key repeats!
        (2) `i != j` is necessary to avoid situation where target is twice one of the values
            
        """

        lookup_table = {}
        for i, num in enumerate(nums):

            # Add pair if not already added
            if lookup_table.get(num, 'np') == 'np':
                lookup_table[num] = i
            
            j = lookup_table.get(target - num, 'np')
            if j != 'np' and i != j:
                return [i, j]

# %%
# O(n) time complexity + O(n) memory
class Solution(object):
    def twoSum(self, nums, target):
        """
        :type nums: List[int]
        :type target: int
        :rtype: List[int]

        Notes (v0.2)
        --------------
        (1) An improvement over previous version. Add yourself after the check to avoid using yourself
            
        """

        lookup_table = {}
        for i, num in enumerate(nums):
            complement = target - num 
            if complement in lookup_table:
                return [i, lookup_table[complement]]
            lookup_table[num] = i
        return []
